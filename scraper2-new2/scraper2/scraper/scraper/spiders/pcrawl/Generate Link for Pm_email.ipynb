# %%
###### READ FILES FROM DATABASE ######
from sqlalchemy import create_engine
import pymysql
import pandas as pd

sqlEngine       = create_engine('mysql+pymysql://nearby_admin:2Zer8_2t4_SAD32f32dDGF3452@nearby2.c9w6hgaskmtt.us-west-1.rds.amazonaws.com/property_outreach', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
frame           = pd.read_sql("SELECT * FROM temp_logs where contact_method = 'Website' and property_contact_url != ''", dbConnection);

pd.set_option('display.expand_frame_repr', False)
print(frame)
df_logs = frame
dbConnection.close()
df_logs
# Out:
#            id  applicant_id           customer_name customer_phone customer_email                            property_name                                       full_address                          address             city state_code  ...                 property_website website_phone                               property_contact_url pm_website_applied                 pm_company_website pm_company_phone                                              notes  agent_id          updated_at          created_at
# ...

# %%
from datetime import datetime, timedelta
yesterday = datetime.now() - timedelta(3)
yesterday = datetime.strftime(yesterday, '%Y-%m-%d')
print (yesterday)
df_logs = df_logs[df_logs['created_at']> yesterday]
df_logs = df_logs.reset_index()
df_logs['index'] = df_logs.index+1
df_logs
# Out:
# 2022-09-02
#      index      id  applicant_id           customer_name customer_phone customer_email                               property_name                                    full_address                    address            city  ...                  property_website website_phone                               property_contact_url pm_website_applied                 pm_company_website pm_company_phone                                              notes  agent_id          updated_at          created_at
# ...

# %%
###### READ FILES FROM DATABASE ######
from sqlalchemy import create_engine
import pymysql
import pandas as pd

 

sqlEngine       = create_engine('mysql+pymysql://nearby_admin:2Zer8_2t4_SAD32f32dDGF3452@nearby2.c9w6hgaskmtt.us-west-1.rds.amazonaws.com/property_outreach', pool_recycle=3600)
dbConnection    = sqlEngine.connect()
frame           = pd.read_sql("select * from listings", dbConnection);

 

pd.set_option('display.expand_frame_repr', False)
print(frame)
df_listings_db = frame
dbConnection.close()
df_listings_db
# Out:
#           id  status                date                                      property_name                                    full_address                      address              city state_code zipcode    state_name  ...  price_confirmed price_nego  lowcredit_eligibility units_in_complex                                              notes  pm_id  pm_website_applied                    property_website website_phone                                website_contact_url
# 0          1    None 2020-11-29 16:00:00                       1131 E North Ln, Phoenix, AZ               10002 N 7th St, Phoenix, AZ 85020               10002 N 7th St           phoenix         AZ   85020       arizona  ...                1          0                      1             None  2BR for $1180 available for immediate move in....      1                 NaN                                None          None                                               None
# ...

# %%
df_listings_db['together'] = df_listings_db['property_name'].str.lower() + ' | ' + df_listings_db['full_address'].str.lower()
df_logs['together'] = df_logs['property_name'].str.lower() + ' | ' + df_logs['full_address'].str.lower()

# %%
df_merge_logs = pd.merge(df_logs,df_listings_db[['id','pm_id','together']], on='together', how='left')
df_merge_logs = df_merge_logs.drop_duplicates('index')
df_merge_logs = df_merge_logs.reset_index()
df_merge_logs['index'] = df_merge_logs.index+1
df_merge_logs = df_merge_logs.drop(columns={'level_0'})
df_merge_logs = df_merge_logs.rename(columns={'id_x':'logs_id', 'id_y':'listing_id'})
df_merge_logs
# Out:
#      index  logs_id  applicant_id           customer_name customer_phone customer_email                               property_name                                    full_address                    address            city  ... pm_website_applied                 pm_company_website pm_company_phone                                              notes agent_id          updated_at          created_at                                           together  listing_id  pm_id
# 0        1   328270       3711536      Kathleen Martenson     7026210132           None                                  Studio 629               608 S 1st St, Las Vegas, NV 89101               608 S 1st St       las vegas  ...                  0                               None             None  studio available for $1143 a month\r\nthey do ...       10 2022-09-02 15:11:19 2022-09-02 15:11:19     studio 629 | 608 s 1st st, las vegas, nv 89101       29068  35961
# ...

# %%
a = df_merge_logs["customer_name"].str.split(" ", n = 2, expand = True)
df_merge_logs['first_name'] = a[0]
df_merge_logs['template'] = "Hi there,\n\nIt was great speaking with you regarding the home in " + df_merge_logs['full_address'].astype(str) + "\nWe're looking forward to connecting you with our client - " + df_merge_logs['first_name'].astype(str) + ".\nAs mentioned in the call, please visit the site below to view additional details.\n\nSite: https://landlord.rentown.net/?auto=" + df_merge_logs['applicant_id'].astype(str) + "&lid=" + df_merge_logs['listing_id'].astype(str) + "&pmid=" + df_merge_logs['pm_id'].astype(str) + "&source=sw&type=pmwebsite \n\nPlease feel free to write back for any questions or concerns.\n\nAll the best,\n\nJennifer Jones\nCustomer Success Manager | RentOwn"
cols = ['index','property_contact_url','template']
df_merge_logs = df_merge_logs[cols]
df_merge_logs
# Out:
#      index                               property_contact_url                                           template
# 0        1              studio629.residentportal.com/contact/  Hi there,\n\nIt was great speaking with you re...
# 1        2  bayoulandingapts.com/apartments/ms/gulfport/co...  Hi there,\n\nIt was great speaking with you re...
# 2        3                 parkplace-apartments.com/contactus  Hi there,\n\nIt was great speaking with you re...
# 3        4                          theartsdallas.com/contact  Hi there,\n\nIt was great speaking with you re...
# 4        5                interurbanbuilding.com/Contact.aspx  Hi there,\n\nIt was great speaking with you re...
# 5        6                       asherresidences.com/contact/  Hi there,\n\nIt was great speaking with you re...
# 6        7                       avenueloftstampa.com/contact  Hi there,\n\nIt was great speaking with you re...
# ...

# %%
df_merge_logs.to_excel('try_template.xlsx')
